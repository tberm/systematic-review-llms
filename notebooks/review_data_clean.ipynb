# %%
import pandas as pd

# %%
# %cd ../data/covidence
from pathlib import Path
paths = list(Path('.').glob('*/full.csv'))
reviews = [path.parts[0] for path in paths]
# Out:
# /home/tom/msc/diss/experiments/data/covidence
# /home/tom/anaconda3/envs/diss/lib/python3.12/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from pathlib import Path

def describe_data():
    datasets = []
    for path in Path('.').glob('*/full.csv'):
        df = pd.read_csv(path)
        datasets.append({
            'review': path.parts[0],
            'items': len(df),
            'pos_items': df.label.sum(),
            'pos_frac': df.label.sum() / len(df),
        })
    return pd.DataFrame(datasets)

describe_data()
# Out:
#           review  items  pos_items  pos_frac
# 0  review_378562    643         98  0.152411
# 1  review_240084    599        130  0.217028
# 2  review_334317   4365        126  0.028866
# 3  review_287708   1360        256  0.188235
# 4  review_121733   3707       1373  0.370380
# 5  review_288055   1381         26  0.018827
# 6  review_165805   2292        239  0.104276
# 7  review_117787   1330        142  0.106767
# 8  review_258698   6976        213  0.030533

# %%
def update_review_criteria():
    df = pd.read_csv('reviews.csv', index_col=0)
    for path in Path('.').glob('*/standard_criteria.txt'):
        with path.open() as crit_file:
            criteria = crit_file.read()
        review = int(path.parts[0].split('_')[1])
        df.loc[review, 'criteria'] = criteria.strip()
    df.to_csv('reviews.csv')

update_review_criteria()

# %%
import fasttext
import numpy as np

from huggingface_hub import hf_hub_download

# monkey patch to remove annoying warning
fasttext.FastText.eprint = lambda x: None

model_path = hf_hub_download(repo_id="facebook/fasttext-language-identification", filename="model.bin")
model = fasttext.load_model(model_path)
#out = model.predict(["this wasn't meant for you anyway", 'you know'], k=5)

def is_english(text, threshold=0.01, k=4):
    preds = model.predict(text, threshold=threshold, k=k)[0]
    return np.array([
        '__label__eng_Latn' in pred for pred in preds
    ])

# %%
def simplify_columns(df):
    df = df[['orig_index', 'Title', 'Abstract', 'label', 'review_id']]
    return df.rename(columns={'Title': 'title', 'Abstract': 'abstract'})

# %%
def load_papers(review_path):
    included = pd.read_csv(review_path + '/' + 'included.csv')
    included['label'] = 1
    excluded = pd.read_csv(review_path + '/' + 'excluded.csv')
    excluded['label'] = 1
    irrelevant = pd.read_csv(review_path + '/' + 'irrelevant.csv')
    irrelevant['label'] = 0
    for frame in (included, excluded, irrelevant):
        frame['orig_index'] = frame.index
    
    full_df = pd.concat([included, excluded, irrelevant])
    full_df = full_df.reset_index()
    return full_df

# %%
def find_duplicates(df):
    title_counts = df.groupby('Title').count()
    dup_titles = title_counts[title_counts.Authors > 1]
    return df[df.Title.isin(dup_titles.index)].sort_values('Title')

# %%
def remove_no_abstract(df):
    orig_len = len(df)
    filtered = df[(df.Abstract != '') & (~df.Abstract.isnull())]
    print(f'{orig_len - len(filtered)} rows removed')
    return filtered

# %%
def remove_not_english(df):
    orig_len = len(df)
    is_eng = is_english(df.Abstract.to_list())
    return df[is_eng], df[~is_eng]

# %% [markdown]
# ### Cleaning each review dataset

# %%
df = load_papers('review_288055')
df = remove_no_abstract(df)
# gave lots of false positives, just remove one german one
# df, df_non_eng = remove_not_english(df)
df = df.drop(1540)
# one duplicate
# find_duplicates(df)
df = df.drop(1532)
df['review_id'] = 288055
simplify_columns(df).to_csv('review_288055/full.csv')
# Out:
# 1057 rows removed

# %%
df = load_papers('review_258698')
df = remove_no_abstract(df)

# 466 non-eng!
#df, df_non_eng = remove_not_english(df)
#df_non_eng.to_csv('review_258698/non_eng.csv')

find_duplicates(df)
#dups_to_remove = [3017, 830, 2577, 3233, 4782, 4133]
df = df.drop(dups_to_remove)
df['review_id'] = 258698
simplify_columns(df).to_csv('review_258698/full.csv')
# Out:
# 57 rows removed
#       index                                              Title  \
# 3016   2794  Development of an immunochromatographic strip ...
# 3017   2795  Development of an immunochromatographic strip ...
# 829     607  Epidemiology of gout and hyperuricemia in New ...
# 830     608  Epidemiology of gout and hyperuricemia in New ...
# 620     398  Experience of pediatric rapid response team in...
# 2577   2355  Experience of pediatric rapid response team in...
# 3232   3010  Medical and substance use comorbidity in bipol...
# 3233   3011  Medical and substance use comorbidity in bipol...
# 4781   4559  Non-protective immunity against tetanus in pri...
# 4782   4560  Non-protective immunity against tetanus in pri...
# 3505   3283  Short-term mobility and the risk of HIV infect...
# 4133   3911  Short-term mobility and the risk of HIV infect...
#
#                                                 Authors  \
# 3016  Ji, Fang; Mokoena, Mduduzi P.; Zhao, Hongyan; ...
# 3017  Ji, F.; Mokoena, M. P.; Zhao, H.; Olaniran, A....
# 829   Bardin, Thomas; Magnat, Elodie; Clerson, Pierr...
# 830   Bardin, Thomas; Magnat, Elodie; Clerson, Pierr...
# 620   Anwar ul, Haque; Saleem, Ali Faisal; Zaidi, Sa...
# 2577                                          Haque, A.
# 3232  Kemp, D. E.; Gao, K.; Ganocy, S. J.; Caldes, E...
# 3233  Kemp, D. E.; Gao, K.; Ganocy, S. J.; Caldes, E...
# 4781  Orimadegun, Adebola Emmanuel; Orimadegun, Bose...
# 4782  Orimadegun, Adebola Emmanuel; Orimadegun, Bose...
# 3505  Kwena, Zachary A.; Camlin, Carol S.; Shisanya,...
# 4133  Mbugua, N.; Bukusi, E. A.; Mwanzo, I.; Kwena, ...
#
#                                                Abstract  Published Year  \
# 3016  A colloidal gold (ICS) test was developed for ...          2017.0
# 3017  A colloidal gold (ICS) test was developed for ...          2019.0
# 829   Objectives: New Caledonia is a Pacific island ...          2021.0
# 830   OBJECTIVES: New Caledonia is a Pacific island ...          2022.0
# 620   OBJECTIVE: To report our experience before and...          2010.0
# 2577  Introduction: The concept of rapid response te...          2009.0
# 3232  Objective: National Comorbidity Survey data in...          2009.0
# 3233  Objective: National Comorbidity Survey data in...          2010.0
# 4781  Introduction: Nigeria remains among the few co...          2008.0
# 4782  INTRODUCTION: Nigeria remains among the few co...          2017.0
# 3505  OBJECTIVE: Mobility has long been associated w...          2013.0
# 4133  Introduction Mobility has long been associated...          2017.0
#
#      Published Month                          Journal Volume         Issue  \
# 3016             NaN                         PLoS ONE     12             5
# 3017             NaN                          Toxicon    158  Supplement 1
# 829              NaN                 Joint Bone Spine     88             5
# 830              NaN                 Joint Bone Spine     89             2
# 620              NaN     Indian Journal of Pediatrics     77             3
# 2577             NaN           Critical Care Medicine     37     12 SUPPL.
# 3232             NaN   Journal of Affective Disorders    116           1-2
# 3233             NaN            Psiquiatria Biologica     17             4
# 4781             NaN                  Pan Afr. med. j    NaN           NaN
# 4782             NaN  The Pan African medical journal     27       Suppl 3
# 3505             NaN                         PLoS ONE      8             1
# 4133             NaN  Sexually Transmitted Infections     93  Supplement 2
#
#       Pages  Accession Number  \
# 3016    NaN               NaN
# 3017    NaN               NaN
# 829     NaN               NaN
# 830     NaN               NaN
# 620     NaN               NaN
# 2577    NaN               NaN
# 3232    NaN               NaN
# 3233    NaN               NaN
# 4781    NaN               NaN
# 4782    NaN               NaN
# 3505    NaN               NaN
# 4133    NaN               NaN
#
#                                                     DOI  Ref Covidence #  \
# 3016    https://dx.doi.org/10.1371/journal.pone.0175282  NaN       #2898
# 3017   https://dx.doi.org/10.1016/j.toxicon.2018.10.228  NaN       #2899
# 829                        10.1016/j.jbspin.2021.105286  NaN        #632
# 830     https://dx.doi.org/10.1016/j.jbspin.2021.105286  NaN        #633
# 620        https://dx.doi.org/10.1007/s12098-010-0032-2  NaN        #418
# 2577  https://dx.doi.org/10.1097/01.ccm.0000365439.1...  NaN       #2438
# 3232                          10.1016/j.jad.2008.11.011  NaN       #3122
# 3233                         10.1016/j.psiq.2010.12.002  NaN       #3123
# 4781                                                NaN  NaN       #4731
# 4782  https://dx.doi.org/10.11604/pamj.supp.2017.27....  NaN       #4732
# 3505    https://dx.doi.org/10.1371/journal.pone.0054523  NaN       #3402
# 4133  https://dx.doi.org/10.1136/sextrans-2017-05326...  NaN       #4051
#
#                 Study Notes Tags  label  orig_index preproc_tag
# 3016          Ji 2017   NaN  NaN      0        2794         NaN
# 3017          Ji 2019   NaN  NaN      0        2795         NaN
# 829       Bardin 2021   NaN  NaN      0         607         NaN
# 830       Bardin 2022   NaN  NaN      0         608         NaN
# 620      Anwarul 2010   NaN  NaN      0         398         NaN
# 2577       Haque 2009   NaN  NaN      0        2355         NaN
# 3232        Kemp 2009   NaN  NaN      0        3010         NaN
# 3233        Kemp 2010   NaN  NaN      0        3011         NaN
# 4781  Orimadegun 2008   NaN  NaN      0        4559         NaN
# 4782  Orimadegun 2017   NaN  NaN      0        4560         NaN
# 3505       Kwena 2013   NaN  NaN      0        3283         NaN
# 4133      Mbugua 2017   NaN  NaN      0        3911         NaN

# %%
df = load_papers('review_287708')
df = remove_no_abstract(df)
# no dups
# find_duplicates(df)
df['review_id'] = 287708
simplify_columns(df).to_csv('review_287708/full.csv')
# Out:
# 46 rows removed

# %%
df = load_papers('review_117787')
df = remove_no_abstract(df)

# none flagged as non-english
# df, df_non_eng = remove_not_english(df)

# one duplicate
#find_duplicates(df)
df = df.drop(543)

df['review_id'] = 117787
simplify_columns(df).to_csv('review_117787/full.csv')
# Out:
# 169 rows removed

# %%
df = load_papers('review_378562')
df = remove_no_abstract(df)

# df, df_non_eng = remove_not_english(df)

# one duplicate
# find_duplicates(df)
df = df.drop(540)

df['review_id'] = 378562
simplify_columns(df).to_csv('review_378562/full.csv')
# Out:
# 83 rows removed

# %%
df = load_papers('review_334317')
df = remove_no_abstract(df)

df, df_non_eng = remove_not_english(df)

find_duplicates(df)
dup_ids = [1439, 3638, 2378, 3698, 2313, 2268, 739, 2856, 3453, 3424, 3866, 3323, 3206, 3671, 1008,
           3926, 3947, 82, 3527, 2683, 2917, 2643, 3680, 3347]
df = df.drop(dup_ids)

df['review_id'] = 334317
simplify_columns(df).to_csv('review_334317/full.csv')
# Out:
# 77 rows removed

# %%
df = load_papers('review_165805')
df = remove_no_abstract(df)

df, df_non_eng = remove_not_english(df)

dup_ids = [294, 1371, 1043, 537, 300, 2362, 95, 1074, 1923, 2001, 2091, 2616, 2202]
df = df.drop(dup_ids)

df['review_id'] = 165805
simplify_columns(df).to_csv('review_165805/full.csv')
# Out:
# 338 rows removed

# %%
df = load_papers('review_240084')
df = remove_no_abstract(df)

# only one, which has abstract in 3 langs
#df, df_non_eng = remove_not_english(df)

df['review_id'] = 240084
simplify_columns(df).to_csv('review_240084/full.csv')
# Out:
# 19 rows removed

# %% [markdown]
# ### Create various splits of the datasets

# %% [markdown]
# Create cut down datasets for 0-shot evaluation -- we want to have as many examples of positive and negative as possible up to a reasonable threshold, let's say 300.
#
# Note we are not shuffling!

# %%
reviews = ['review_240084']

for review in reviews:
    df = pd.read_csv(f'{review}/full.csv', index_col=0)
    pos = df[df.label == 1]
    neg = df[df.label == 0]
    if len(pos) > 300:
        pos = pos.sample(300)
    if len(neg) > 300:
        neg = neg.sample(300)

    df = pd.concat([pos, neg])
    df.to_csv(f'{review}/zero-shot-eval.csv')

# %%
def make_splits(review_dir):
    df = pd.read_csv(review_dir + '/full.csv', index_col=0)
    
    rng = np.random.default_rng(24)
    df = df.sample(frac=1)
    
    # first take the validation sample
    cutoff = np.ceil(len(df) * 0.15).astype(int)
    val_split = df.iloc[:cutoff]
    train_split_1 = df.iloc[cutoff:]
    
    pos_train_count = train_split_1.label.sum()
    train_split_2 = pd.concat([
        train_split_1[train_split_1.label == 1],
        train_split_1[train_split_1.label == 0].sample(pos_train_count),
    ])
    
    print(f'Validation set: {len(val_split)} items')
    print(f'Train split 1: {len(train_split_1)} items ({pos_train_count} positive)')
    print(f'Train split 2: {len(train_split_2)} items ({train_split_2.label.sum()} positive)')
    
    np.savetxt(review_dir + '/val_split.txt', val_split.index.to_numpy())
    np.savetxt(review_dir + '/natural_train_split.txt', train_split_1.index.to_numpy())
    np.savetxt(review_dir + '/balanced_train_split.txt', train_split_2.index.to_numpy())

# %%
def make_cross_val_splits(review_dir):
    df = pd.read_csv(review_dir + '/full.csv', index_col=0)
    
    rng = np.random.default_rng(24)
    df = df.sample(frac=1)

    val_split_size = int(0.2 * len(df))
    for split_num, split_label in enumerate('ABCDE'):

        val_idxs = df.iloc[split_num * val_split_size : (split_num + 1) * val_split_size].index
        val_fold = df.loc[val_idxs]
        unbal_train_fold = df.drop(index=val_idxs)
        num_pos_items = unbal_train_fold.label.sum()
        bal_train_fold = pd.concat([
            unbal_train_fold[unbal_train_fold.label == 1],
            unbal_train_fold[unbal_train_fold.label == 0].sample(num_pos_items)
        ])
        np.savetxt(review_dir + f'/sm-val-fold-{split_label}.txt', val_idxs)
        #np.savetxt(review_dir + f'/train-fold-{split_label}.txt', bal_train_fold.index)

        sm_train_fold = unbal_train_fold.sample(196)
        np.savetxt(review_dir + f'/sm-train-fold-{split_label}.txt', sm_train_fold.index)

# %%
make_cross_val_splits('review_117787')
make_cross_val_splits('review_121733')
make_cross_val_splits('review_165805')
make_cross_val_splits('review_258698')
make_cross_val_splits('review_287708')
make_cross_val_splits('review_334317')
make_cross_val_splits('review_378562')

# %%
def load_fold(name):
    df = pd.read_csv('review_121733/full.csv', index_col=0)
    idxs = np.genfromtxt('review_121733/' + name)
    return df.loc[idxs]

# %%
review = 121733
fold = 'A'

for review in (117787, 121733, 165805, 258698, 287708, 334317):
    for fold in 'ABCDE':
        df = pd.read_csv(f'review_{review}/full.csv', index_col=0)
        idx = np.genfromtxt(f'review_{review}/sm-train-fold-{fold}.txt')
        free_df = df.drop(index=idx)
        few_shot = pd.concat([
            free_df[free_df.label == 1].sample(25),
            free_df[free_df.label == 0].sample(25),
        ])
        unseen_val = free_df.drop(index=few_shot.index)
        np.savetxt(f'review_{review}/few-shot-fold-{fold}.txt', few_shot.index)
        np.savetxt(f'review_{review}/unseen-fold-{fold}.txt', unseen_val.index)

# %%
#make_splits('review_287708')
#make_splits('review_121733')
#make_splits('review_258698')
#make_splits('review_378562')
#make_splits('review_334317')
#make_splits('review_165805')
make_splits('review_240084')
# Out:
# Validation set: 90 items
# Train split 1: 509 items (116 positive)
# Train split 2: 232 items (116 positive)

# %%
# Make full sets that are not quite full sets for reviews that are really big
import numpy as np

df = pd.read_csv('review_121733/full.csv', index_col=0)    
df = df.sample(740)
np.savetxt('review_121733/trunc_full.txt', df.index.to_numpy())

df = pd.read_csv('review_258698/full.csv', index_col=0)    
df = df.sample(5200)
np.savetxt('review_258698/trunc_full.txt', df.index.to_numpy())

# %%
# Make "few-shot" sets for the case when we have a few labelled samples from the target review
import numpy as np

for review in (117787, 121733, 165805, 240084, 258698, 287708, 334317, 378562):
    df = pd.read_csv(f'review_{review}/full.csv', index_col=0)
    few_shot_df = pd.concat([
        df[df.label == 1].sample(25),
        df[df.label == 0].sample(25),
    ]).sample(frac=1)
    few_shot_df.to_csv(f'review_{review}/few_shot.csv')

# %%
# Make natural few shot sets
import numpy as np

for review in (117787, 121733, 165805, 240084, 258698, 287708, 334317, 378562):
    df = pd.read_csv(f'review_{review}/full.csv', index_col=0)
    few_shot_df = df.sample(50)
    pos_count = few_shot_df.label.sum()
    # we want at least 5 pos
    if pos_count >= 5:
        few_shot_df.to_csv(f'review_{review}/nat_few_shot.csv')
        continue
        
    pos_needed = 5 - pos_count
    few_shot_df = pd.concat([
        few_shot_df.iloc[:-pos_needed],
        df[df.label == 1].sample(pos_needed),
    ]).sample(frac=1)
    few_shot_df.to_csv(f'review_{review}/nat_few_shot.csv')

# %%
# retrospectively make complementary evaluation splits to the few shot splits
# for review in (117787, 121733, 165805, 240084, 258698, 287708, 334317, 378562):
for review in (121733, 258698):
    df = pd.read_csv(f'review_{review}/full.csv', index_col=0)
    few_shot_df = pd.read_csv(f'review_{review}/few_shot.csv', index_col=0)
    remain = df.drop(index=few_shot_df.index)
    if review == 121733:
        remain = remain.sample(740)
    if review == 258698:
        remain = remain.sample(5200)
    np.savetxt(f'review_{review}/few_shot_complement.txt', remain.index)

# %%
# retrospectively make complementary datasets to the natural few shots
for review in (117787, 121733, 165805, 240084, 258698, 287708, 334317, 378562):
    df = pd.read_csv(f'review_{review}/full.csv', index_col=0)
    few_shot_df = pd.read_csv(f'review_{review}/nat_few_shot.csv', index_col=0)
    remain = df.drop(index=few_shot_df.index)
    if review == 121733:
        remain = remain.sample(740)
    if review == 258698:
        remain = remain.sample(5200)
    np.savetxt(f'review_{review}/nat_few_shot_complement.txt', remain.index)

# %%
# make a smaller multi-review evaluation subset
sets = []
for review in (117787, 121733, 165805, 258698, 287708, 334317, 378562):
    df = pd.read_csv(f'review_{review}/full.csv', index_col=0)
    df['df_index'] = df.index
    idx = np.genfromtxt(f'review_{review}/nat_few_shot_complement.txt')
    eval_set = df.loc[idx]
    subset = eval_set.sample(60)
    sets.append(subset)
    extra_pos = eval_set[eval_set.label == 1].sample(5)
    sets.append(extra_pos)
    
mr_subset = pd.concat(sets).sample(frac=1)
mr_subset.label.sum()
# Out:
# 98

# %%
# Set of items to use for in-context examples

sets = []
reviews = np.array([117787, 121733, 165805, 258698, 287708, 334317, 378562])
for review in reviews:
    df = pd.read_csv(f'review_{review}/nat_few_shot.csv', index_col=0)
    sets.append(df)

all_fs_train = pd.concat(sets).sample(frac=1)
np.random.shuffle(reviews)
signs = [0, 1, 0, 1]
train_idxs = []
for rev_id, sign in zip(reviews[:4], signs):
    train_idxs.append(all_fs_train[
        (all_fs_train.review_id == rev_id)
        & (all_fs_train.label == sign)
    ].index[0])

train_idxs

examples_set = all_fs_train.loc[train_idxs]
examples_set
# Out:
#       orig_index                                              title  \
# 614          440  Disease burden of community acquired pneumonia...
# 105           61  Perceptions of suicide and their impact on pol...
# 1706        1706  A stable filamentous coaxial microelectrode fo...
# 118          106  Clinical characteristics and severity of COVID...
#
#                                                abstract  label  review_id
# 614   Background: To obtain the baseline data on the...      0     117787
# 105   In recent years, there has been an increase in...      1     334317
# 1706  By using a facile spray drying method, we fabr...      0     121733
# 118   Resumen Introducción: Se ha señalado que facto...      1     165805

# %%
examples_set.to_csv('multi_review_examples.csv')

# %%
mr_subset[['review_id', 'df_index']].to_csv('multi_review_eval_subset.csv', index=False)

# %%
# the final test set
df = pd.read_csv('review_240084/full.csv', index_col=0)
few_shot_df = pd.read_csv('review_240084/nat_few_shot.csv', index_col=0)
remain = df.drop(index=few_shot_df.index)
np.savetxt(f'review_240084/nat_few_shot_complement.txt', remain.index)

# %%
few_shot_240 = pd.read_csv('review_240084/nat_few_shot.csv', index_col=0)
# Out:
#      orig_index                                              title  \
# 54           46  COVID-19 recovery from the community perspecti...
# 131         123  Recovery, resilience and growth regimes under ...
# 320         184  Investigating the challenges and opportunities...
# 252         116  COVID-19 impact on Surgical Training and Recov...
# 239         103     An Analytical Perspective on Pandemic Recovery
# 285         149  A qualitative exploration of the impact of COV...
# 596         460  Sustainable economic development in the Europe...
# 190          54  Headwinds across the Balkans: economic growth ...
# 206          70  One Piece of the Jigsaw for the Cancer Recover...
# 473         337  Disaster Planning During SARS-CoV-2/COVID: One...
# 133         125  Optimizing Strategies for Improving Mental Hea...
# 88           80  INSTITUTIONAL DYNAMICS AND ECONOMIC RESILIENCE...
# 420         284  Implementing digital technology during the pan...
# 233          97  Flattening the Risk: Pre-Exposure Prophylaxis ...
# 364         228  Impacts of COVID-19 Pandemic on the Road and T...
# 366         230  Impact of the COVID-19 Pandemic on the Employm...
# 256         120  Assessment of Supply Chain Management Resilien...
# 486         350  Communicating COVID-19 health information to c...
# 38           30  A New Normal or Business-as-Usual? Lessons for...
# 405         269  Indonesia-Australia Comprehensive Economic Par...
# 1             1  Green New Deal proposals: Comparing emerging t...
# 331         195  Digital sexual health: what we know and what w...
# 481         345  Global NO2 Dynamics During the COVID-19 Pandem...
# 204          68  "Now It's Just Old Habits and Misery"-Understa...
# 530         394  What has been done and what has not – the gove...
# 412         276  BNT162b2 COVID-19 Vaccine Hesitancy among Pare...
# 283         147  Becoming a Yam: Healing Narratives as Politica...
# 241         105  Mental resilience to stressor prevalence and s...
# 278         142  Critical illness neuropathy in severe COVID-19...
# 6             6  THE "1.degrees DIREITO" LEVER: A LOOK AT THE F...
# 296         160  Recovery strategies following COVID-19 disrupt...
# 63           55  S3 and Recovery and Resilience Funds: A Case S...
# 609         473  A mixed-methods study on the design of Artific...
# 417         281  Which Social, Economic, and Health Sector Stra...
# 186          50  Inferring COVID-19 spreading rates and potenti...
# 145           9  Consuming safe hotels during the COVID-19 pand...
# 14            6  PANDEMIC AND BUDGET BALANCE, A COMPARATIVE STU...
# 92           84  Empower Eco multiactor HUB: A triple helix ‘ac...
# 545         409  Exploratory research on the adoption of compos...
# 201          65  Psychosocial risks and work stress in times of...
# 45           37  COVID-19's Impact on American Women's Food Ins...
# 576         440  National Development Banks in Europe – A Contr...
# 255         119  A Comparative Study on Pandemic Response and T...
# 116         108  Operating, financial and investment impacts of...
# 502         366  National Health Service interventions in Engla...
# 527         391  The impact of COVID-19 on O&G trainees; where ...
# 299         163  Decommissioning and recommissioning a regional...
# 365         229  Patriarchy at the helm of gender-based violenc...
# 4             4  High-level meeting on health systems resilienc...
# 517         381  A multi-stage supply chain disruption mitigati...
#
#                                               abstract  label  review_id
# 54   Background: People younger than 65 years livin...      1     240084
# 131  This paper attempts to weigh into the debate o...      1     240084
# 320  INTRODUCTION: Hospital admissions from COVID-1...      0     240084
# 252  BACKGROUND: The COVID-19 pandemic has resulted...      0     240084
# 239  After implementing restrictions to curb the sp...      0     240084
# 285  COVID-19 may have substantial impact on the me...      0     240084
# 596  The paper has two basic objectives. The first,...      0     240084
# 190  This paper provides comparison of economic gro...      0     240084
# 206  COVID-19 has forced governments to make drasti...      0     240084
# 473  Disasters cause a major disruption to normal o...      0     240084
# 133  The ongoing COVID-19 pandemic has impacted the...      1     240084
# 88   In the global context generated by the 2008-20...      1     240084
# 420  The COVID-19 pandemic has been one of the grea...      0     240084
# 233  To date, more than 35 million people worldwide...      0     240084
# 364  The road and transport industry are few of the...      0     240084
# 366  OBJECTIVE: The COVID-19 pandemic has had consi...      0     240084
# 256  Covid-19 pandemic has affected global supply c...      0     240084
# 486  OBJECTIVE: To consider the challenges of commu...      0     240084
# 38   Crises and dislocations home in on social, eco...      1     240084
# 405  This article intends to explain the impact of ...      0     240084
# 1    Green New Deal (GND) policy proposals that sim...      1     240084
# 331  Many countries' health strategies promote a la...      0     240084
# 481  Nitrogen dioxide (NO2) as one of the key pollu...      0     240084
# 204  Background: Many aspects of the Covid-19 pande...      0     240084
# 530  Purpose: This paper aims to examine Canadian g...      0     240084
# 412  Parental vaccine hesitancy (VH) remains a barr...      0     240084
# 283  COVID-19 created a crisis that forced people t...      0     240084
# 241  Background: The rising prevalence of stress-re...      0     240084
# 278  Introduction: Neurological complications of SA...      0     240084
# 6    Housing is today a well-known theme in the Por...      1     240084
# 296  Background: The COVID-19 pandemic has disrupte...      0     240084
# 63   The EU's response to the COVID-19 crisis, name...      1     240084
# 609  Background: Artificial Intelligence (AI) and d...      0     240084
# 417  Background: Current global challenges are gene...      0     240084
# 186  As COVID-19 is rapidly spreading across the gl...      0     240084
# 145  Since the beginning of the COVID-19 pandemic, ...      0     240084
# 14   The fight against the pandemic generated by Co...      1     240084
# 92   There is a pressing drive to address climate c...      1     240084
# 545  Biowaste management presents one of the bigges...      0     240084
# 201  In the world, every year almost three million ...      0     240084
# 45   The COVID-19 pandemic is wreaking havoc on hum...      1     240084
# 576  Prispevek pojasnjuje ključne spremembe financi...      0     240084
# 255  Coronavirus strikes again with the delta varia...      0     240084
# 116  Currently, many institutions and academics are...      1     240084
# 502  Armed Forces veterans (AFVs) are first and for...      0     240084
# 527  Background and Objectives: Obstetrics and Gyna...      0     240084
# 299  CONTEXT: The COVID-19 outbreak at the North We...      0     240084
# 365  Gender-based violence (GBV) or violence agains...      0     240084
# 4    This high-level meeting addressed health syste...      1     240084
# 517  The global pandemic of COVID-19 has caused sev...      0     240084

# %%
# split in half
for review in (117787, 121733, 165805, 240084, 258698, 287708, 288055, 334317, 378562):
    df = pd.read_csv(f'review_{review}/full.csv', index_col=0)

    if review in (121733, 258698):
        trunc_split = np.genfromtxt(f'review_{review}/trunc_full.txt')
        df = df.loc[trunc_split]
    
    df_pos = df[df.label == 1].sample(frac=1)
    df_neg = df[df.label == 0].sample(frac=1)
    
    num_pos = len(df_pos) // 2
    num_neg = len(df_neg) // 2

    df_a = pd.concat([df_pos.iloc[:num_pos], df_neg.iloc[:num_neg]])
    df_b = pd.concat([df_pos.iloc[num_pos:], df_neg.iloc[num_neg:]])

    np.savetxt(f'review_{review}/first_half.txt', df_a.index)
    np.savetxt(f'review_{review}/second_half.txt', df_b.index)

# %%
idx_a = np.genfromtxt('review_258698/first_half.txt')
idx_b = np.genfromtxt('review_258698/second_half.txt')

# %%
len(idx_a), len(idx_b)
# Out:
# (3487, 3489)

# %% [markdown]
# ### Review 121733

# %%
# excluded based on title and abstract
title_abs_excl = pd.read_csv('review_121733/review_121733_irrelevant-after-Title&Abstract-screen.csv')
# conflicting decisions based on title and abstract
conflicts = pd.read_csv('review_121733/review_121733_Conflicts-at-Title&Abstract-screen.csv')

## sets below made it past title and abstract screen
# excluded based on full text
full_text_excl = pd.read_csv('review_121733/review_121733_excluded-after-fulltext-screen.csv')
# full text review not complete
incomplete = pd.read_csv('review_121733/review_121733_fulltext-screen-incomplete.csv')
# included based on full text
included = pd.read_csv('review_121733/review_121733_included-after-fulltext-screen.csv')

# %%
from enum import Enum

class Decision(Enum):
    EXCL = 0
    CONFL = 1
    FT_EXCL = 2
    FT_INCOMP = 3
    FT_INCL = 4

# %%
title_abs_excl['decision'] = Decision.EXCL
conflicts['decision'] = Decision.CONFL
full_text_excl['decision'] = Decision.FT_EXCL
incomplete['decision'] = Decision.FT_INCOMP
included['decision'] = Decision.FT_INCL

frames = [title_abs_excl, conflicts, full_text_excl, incomplete, included]

# %%
full_df = pd.concat(frames)
full_df['orig_index'] = full_df.index
full_df = full_df.reset_index()
full_df
# Out:
#       index                                              Title  \
# 0         0  Simultaneous removal of tetracycline and disin...
# 1         1  A practical method for the calculation of liqu...
# 2         2  Toward better microbial safety of wheat sprout...
# 3         3  Functional collaboration of biofilm-cathode el...
# 4         4  Continuous synthesis of graphene sheets by spr...
# ...     ...                                                ...
# 3842     91  In Vitro Antibacterial Activity of Hydrogen Pe...
# 3843     92  Inactivation of bacteria causing soft rot dise...
# 3844     93  Application of Neutral Electrolyzed Water on p...
# 3845     94  Electrochemically activated solution as bladde...
# 3846     95  Kinetics of Bacterial Inactivation by Peroxyni...
#
#                                                 Authors  \
# 0     Zuo, S.; Zhang, Y.; Ren, G.; Pan, Y.; Zhang, Q...
# 1                            Zuend, A.; Seinfeld, J. H.
# 2                              Zudyte, B.; Luksiene, Z.
# 3                                     Zou, H.; Wang, Y.
# 4       Zou, B.; Wang, X. X.; Huang, X. X.; Wang, J. N.
# ...                                                 ...
# 3842  Raval, Y. S.; Flurin, L.; Mohamed, A.; Greenwo...
# 3843  Song, Hyeyeon; Lee, Jae Yung; Lee, Hae-Won; Ha...
# 3844  Torres-Rosales, E.; Rivera-Garcia, A.; Rosario...
# 3845  Weyler, M.; Jaekel, A.; Kirschner-Hermanns, R....
# 3846  Yokoyama, T.; Miyazaki, S.; Akagi, H.; Ikawa, ...
#
#                                                Abstract  Published Year  \
# 0     Pharmaceutical and personal care products as o...          2019.0
# 1     Liquid mixtures containing a variety of organi...          2013.0
# 2     Sprouted seeds are gaining popularity worldwid...          2019.0
# 3     A distinctive process (BCE-MFC) was developed ...          2019.0
# 4     Graphene sheets (GNS) were synthesized continu...          2015.0
# ...                                                 ...             ...
# 3842  Hydrogen peroxide (H2O2) and hypochlorous acid...          2021.0
# 3843  Slightly acidic electrolyzed water (SAEW), an ...          2021.0
# 3844  Physicochemical and microbiological properties...          2020.0
# 3845  AIMS: Driven by increasing awareness of antibi...          2021.0
# 3846  Low-temperature atmospheric-pressure plasma ha...          2021.0
#
#       Published Month                                            Journal  \
# 0                 NaN                     Journal of Hazardous Materials
# 1                 NaN                               Fluid Phase Equilib.
# 2                 NaN                         Photochem. Photobiol. Sci.
# 3                 NaN  Environmental science and pollution research i...
# 4                 NaN                            Chemical Communications
# ...               ...                                                ...
# 3842              NaN              Antimicrobial Agents and Chemotherapy
# 3843              NaN                                       Food Control
# 3844              NaN                                 Scientific Reports
# 3845              NaN                         Neurourology & Urodynamics
# 3846              NaN               Applied & Environmental Microbiology
#
#      Volume Issue        Pages     Accession Number  \
# 0       368   NaN      771-777           2001546732
# 1       337   NaN      201-213  WOS:000315325500027
# 2        18    10    2521-2530  WOS:000489635100014
# 3        26    22  23061-23069            628271164
# 4        51     4      741-744            600732879
# ...     ...   ...          ...                  ...
# 3842     65     5          NaN                  NaN
# 3843    128   NaN          NaN                  NaN
# 3844     10     1          NaN                  NaN
# 3845     40     7          NaN                  NaN
# 3846     87     2          NaN                  NaN
#
#                                                   DOI     Ref Covidence #  \
# 0     http://dx.doi.org/10.1016/j.jhazmat.2019.02.005  5202.0          #1
# 1                         10.1016/j.fluid.2012.09.034  8644.0          #2
# 2                                  10.1039/c9pp00157c  8643.0          #3
# 3        http://dx.doi.org/10.1007/s11356-019-05617-w  5201.0          #4
# 4                http://dx.doi.org/10.1039/c4cc08197h  5200.0          #5
# ...                                               ...     ...         ...
# 3842                             10.1128/aac.01966-20     NaN       #3680
# 3843                   10.1016/j.foodcont.2021.108217     NaN       #3739
# 3844    https://dx.doi.org/10.1038/s41598-020-76931-4     NaN       #3766
# 3845             https://dx.doi.org/10.1002/nau.24745     NaN       #3799
# 3846          https://dx.doi.org/10.1128/AEM.01860-20     NaN       #3830
#
#                     Study                                              Notes  \
# 0                Zuo 2019                                                NaN
# 1              Zuend 2013                                                NaN
# 2             Zudyte 2019                                                NaN
# 3                Zou 2019                                                NaN
# 4                Zou 2015                                                NaN
# ...                   ...                                                ...
# 3842           Raval 2021                                                NaN
# 3843            Song 2021                                                NaN
# 3844  Torres-Rosales 2020                                                NaN
# 3845          Weyler 2021                                                NaN
# 3846        Yokoyama 2021  Kate Homyer (2022-08-23 03:14:15)(Screen): com...
#
#                                          Tags          decision  orig_index
# 0                                         NaN     Decision.EXCL           0
# 1                                         NaN     Decision.EXCL           1
# 2                                         NaN     Decision.EXCL           2
# 3                                         NaN     Decision.EXCL           3
# 4                                         NaN     Decision.EXCL           4
# ...                                       ...               ...         ...
# 3842                Setting - Clinical, human  Decision.FT_INCL          91
# 3843                Setting - Food processing  Decision.FT_INCL          92
# 3844                Setting - Food processing  Decision.FT_INCL          93
# 3845                Setting - Clinical, human  Decision.FT_INCL          94
# 3846  Setting - Water/Environmental treatment  Decision.FT_INCL          95
#
# [3847 rows x 19 columns]

# %% [markdown]
# #### Check for duplicates

# %%
title_counts = full_df.groupby('Title').count()
dup_titles = title_counts[title_counts.Authors > 1]

full_df[full_df.Title.isin(dup_titles.index)].sort_values('Title')
# Out:
#       index                                              Title  \
# 2601     14  Are reduced concentrations of chlorine-based d...
# 3685   1077  Are reduced concentrations of chlorine-based d...
# 498     498                   Automated endoscope reprocessors
# 1665   1665                   Automated endoscope reprocessors
# 3605    997  Compositions, methods and uses for cleaning, d...
# 3606    998  Compositions, methods and uses for cleaning, d...
# 3132    524  Concerns and strategies for wastewater treatme...
# 3681   1073  Concerns and strategies for wastewater treatme...
# 1598   1598  Functionalization of water as a nonthermal app...
# 2556    142  Functionalization of water as a nonthermal app...
# 519     519  Integrating biometallurgical recovery of metal...
# 2277   2277  Integrating biometallurgical recovery of metal...
# 2757    149  Top-Down Characterization of an Antimicrobial ...
# 3735   1127  Top-Down Characterization of an Antimicrobial ...
#
#                                                 Authors  \
# 2601  Kumar, J.; Cadnum, J.; Wong, Y. K. N.; Mana, T...
# 3685  Kumar, J. A.; Cadnum, J. L.; Jencson, A. L.; D...
# 498   Petersen, B. T.; Adler, D. G.; Chand, B.; Conw...
# 1665  Desilets, D.; Kaul, V.; Tierney, W. M.; Banerj...
# 3605  Alimi, Hojabr; Prasad, Sridhar Govinda; De, Su...
# 3606  Alimi, Hojabr; Prasad, Sridhar Govinda; De, Su...
# 3132  Kataki, S.; Chatterjee, S.; Vairale, M. G.; Sh...
# 3681  Kataki, Sampriti; Chatterjee, Soumya; Vairale,...
# 1598              Esua, O. J.; Cheng, J. H.; Sun, D. W.
# 2556     Esua, Okon Johnson; Cheng, Jun-Hu; Sun, Da-Wen
# 519   Patel, A.; Enman, J.; Gulkova, A.; Guntoro, P....
# 2277  Patel, A.; Enman, J.; Gulkova, A.; Guntoro, P....
# 2757  Wohlgemuth, F.; Gomes, R. L.; Singleton, I.; R...
# 3735  Wohlgemuth, Franziska; Gomes, Rachel L.; Singl...
#
#                                                Abstract  Published Year  \
# 2601  Background. Currently, sporicidal disinfectant...          2019.0
# 3685  Chlorine-based disinfectants are commonly used...          2020.0
# 498   National consensus standards provide guidance ...          2009.0
# 1665  National consensus standards provide guidance ...          2010.0
# 3605  The present specification discloses a composit...          2019.0
# 3606  The present specification discloses a composit...          2020.0
# 3132  Along with outbreak of the pandemic COVID-19 c...          2021.0
# 3681  Along with outbreak of the pandemic COVID-19 c...          2021.0
# 1598  Meat and seafood products present a viable med...          2020.0
# 2556  Meat and seafood products present a viable med...          2021.0
# 519   Industrial activities, such as mining, electro...          2021.0
# 2277  Industrial activities, such as mining, electro...          2021.0
# 2757  We developed a top-down strategy to characteri...          2020.0
# 3735  We developed a top-down strategy to characteri...          2020.0
#
#       Published Month                                         Journal  \
# 2601              NaN                  Open Forum Infectious Diseases
# 3685              NaN           American Journal of Infection Control
# 498               NaN                      Gastrointestinal Endoscopy
# 1665              NaN                      Gastrointestinal Endoscopy
# 3605              NaN                                             NaN
# 3606              NaN                                             NaN
# 3132              NaN           Resources, Conservation and Recycling
# 3681              NaN            Resources Conservation and Recycling
# 1598              NaN  Critical reviews in food science and nutrition
# 2556              NaN  Critical Reviews in Food Science and Nutrition
# 519               NaN                                     Chemosphere
# 2277              NaN                                     Chemosphere
# 2757              NaN                       Frontiers in Microbiology
# 3735              NaN                       Frontiers in Microbiology
#
#                    Volume Issue    Pages     Accession Number  \
# 2601     6 (Supplement 2)   NaN     S439            630694123
# 3685                   48     4      NaN                  NaN
# 498                    69     4  771-776            354342103
# 1665                   72     4  675-680            359707018
# 3605                  NaN   NaN        -  BCI:BCI201900886519
# 3606                  NaN   NaN        -  BCI:BCI202000762625
# 3132  164 (no pagination)   NaN      NaN           2007752849
# 3681                  164   NaN      NaN                  NaN
# 1598                  NaN   NaN     1-19            631362300
# 2556                   61     3      NaN                  NaN
# 519   263 (no pagination)   NaN      NaN           2007893273
# 2277                  263   NaN      NaN                  NaN
# 2757   11 (no pagination)   NaN      NaN            633057374
# 3735                   11   NaN      NaN                  NaN
#
#                                                     DOI     Ref Covidence #  \
# 2601         http://dx.doi.org/10.1093/ofid/ofz360.1085  4153.0       #2177
# 3685      https://dx.doi.org/10.1016/j.ajic.2019.08.027     NaN       #3539
# 498         http://dx.doi.org/10.1016/j.gie.2008.11.037  4541.0        #765
# 1665        http://dx.doi.org/10.1016/j.gie.2010.06.019  3682.0       #2625
# 3605                                                NaN     NaN       #3283
# 3606                                                NaN     NaN       #3284
# 3132  http://dx.doi.org/10.1016/j.resconrec.2020.105156  4079.0       #1820
# 3681                    10.1016/j.resconrec.2020.105156     NaN       #3519
# 1598    http://dx.doi.org/10.1080/10408398.2020.1735297  3749.0       #2520
# 2556                      10.1080/10408398.2020.1735297     NaN       #3428
# 519   http://dx.doi.org/10.1016/j.chemosphere.2020.1...  4518.0        #796
# 2277                  10.1016/j.chemosphere.2020.128306     NaN       #3654
# 2757        http://dx.doi.org/10.3389/fmicb.2020.575157  5056.0        #555
# 3735                          10.3389/fmicb.2020.575157     NaN       #3801
#
#                 Study                                              Notes  \
# 2601       Kumar 2019                  Exclusion reason: Abstract only;
# 3685       Kumar 2020  Gillian Clayton (2022-09-29 22:37:25)(Screen):...
# 498     Petersen 2009                                                NaN
# 1665    Desilets 2010                                                NaN
# 3605       Alimi 2019                                                NaN
# 3606       Alimi 2020  Kate Homyer (2022-09-24 23:53:42)(Select): htt...
# 3132      Kataki 2021                                                NaN
# 3681      Kataki 2021                                                NaN
# 1598        Esua 2020                                                NaN
# 2556        Esua 2021                                                NaN
# 519        Patel 2021                                                NaN
# 2277       Patel 2021                                                NaN
# 2757  Wohlgemuth 2020  Kate Homyer (2022-11-24 00:26:41)(Select): alk...
# 3735  Wohlgemuth 2020  Kate Homyer (2022-11-29 22:57:15)(Select): alk...
#
#                                          Tags            decision  orig_index
# 2601  Setting - Water/Environmental treatment    Decision.FT_EXCL          14
# 3685                Setting - Clinical, human  Decision.FT_INCOMP        1077
# 498                                       NaN       Decision.EXCL         498
# 1665                                      NaN       Decision.EXCL        1665
# 3605  Setting - Water/Environmental treatment  Decision.FT_INCOMP         997
# 3606  Setting - Water/Environmental treatment  Decision.FT_INCOMP         998
# 3132                Setting - Clinical, human  Decision.FT_INCOMP         524
# 3681                                      NaN  Decision.FT_INCOMP        1073
# 1598                                      NaN       Decision.EXCL        1598
# 2556                                      NaN      Decision.CONFL         142
# 519                                       NaN       Decision.EXCL         519
# 2277                                      NaN       Decision.EXCL        2277
# 2757                Setting - Clinical, human  Decision.FT_INCOMP         149
# 3735                                      NaN  Decision.FT_INCOMP        1127

# %%
# terms that come up in notes for papers that we may need to remove from the dataset
note_search_terms = [
    'english',
    'abstract',
    'full text',
    'full article',
    'no full',
    'accident',
    'mistake',
    'access',
    'uoe',
]

def is_important_note(note):
    if pd.isna(note):
        return False
    note = note.lower()
    for term in note_search_terms:
        if term in note:
            return True
    return False

# %%
full_df[full_df.Notes.apply(is_important_note)].to_csv('/tmp/decision_notes.csv')

# %%
# ... manually remove some lines from spreadsheet ...
to_review = pd.read_csv('review_121733/decision_notes_to_review.csv')
to_review
# Out:
#     index  orig_index                                              Title  \
# 0     439         439  Disinfection of crockery and unen by using ele...
# 1     443         443  Infection prevention and patient safety improv...
# 2     460         460  Sporicidal activity in diallyl disulphide oxid...
# 3     480         480  Antimicrobial efficacy of nine different root ...
# 4     528         528  Activity and efficacy of a stable chlorinated ...
# ..    ...         ...                                                ...
# 69   3617        1009  Disinfection effect of neutral electrolyzed wa...
# 70   3619        1011  A first study on the application of an electro...
# 71   3663        1055  A comparative experiment on the three kinds of...
# 72   3701        1093  A Concept for the Reduction of Mucosal SARS-Co...
# 73   3722        1114  Evaluation of Decontamination Efficacy of Elec...
#
#                                               Authors  \
# 0                      Vorobev, M. I.; Shlykov, V. I.
# 1                                    Von Der Weid, D.
# 2   Velazquez-Ramirez, C. I.; Scougall-Vilchis, R....
# 3   van der Vyver, P. J.; Botha, F. S.; de Wet, F. A.
# 4   Pappalardo, G.; Tanner, F.; Roussianos, D.; Pa...
# ..                                                ...
# 69  Zhu, ZhiWei; Li, BaoMing; Li, YongYu; Shang, Y...
# 70  Zytur, Stellan; Bandte, Martina; Rodriguez, Ha...
# 71  Hara, Norika; Fujita, Shoichi; Satake, Yuko; N...
# 72             Mueller, C. A.; Winter, M.; Renner, B.
# 73  Sharma, A. K.; Shukla, S. K.; Kalonia, A.; Sha...
#
#                                              Abstract  Published Year  \
# 0   The structure of an electrolysor for electroly...            1962
# 1   Introduction: The technology developed by Ante...            2015
# 2   BACKGROUND: Ineffective instrument reprocessin...            2015
# 3                                                 NaN            2014
# 4                                                 NaN            1982
# ..                                                ...             ...
# 69  For the sake of developing an effective, safe ...            2010
# 70                                                NaN            2016
# 71  Xanthomonas citri pv. citri and X. citri pv. a...            2020
# 72  During the next few months or years, vaccinati...            2021
# 73  Background: Sulfur Mustard is a strong vesican...            2022
#
#     Published Month                                            Journal  \
# 0               NaN  Zhurnal Mikrobiologii Epidemiologii i Immunobi...
# 1               NaN  Antimicrobial Resistance and Infection Control...
# 2               NaN              American Journal of Infection Control
# 3               NaN  SADJ : journal of the South African Dental Ass...
# 4               NaN                                        Experientia
# ..              ...                                                ...
# 69              NaN  Transactions of the Chinese Society of Agricul...
# 70              NaN  60 German Plant Protection Conference - Short ...
# 71              NaN  Research Bulletin of the Plant Protection Serv...
# 72              NaN                                      Drug Research
# 73              NaN               Current Pharmaceutical Biotechnology
#
#                  Volume     Issue             Pages     Accession Number  \
# 0                   NaN       NaN              9-14            281516414
# 1                     4  SUPPL. 1               NaN             72038880
# 2   43 (6 Supplement 1)       NaN           S26-S27            614159542
# 3                    69         4  158-160, 162-165            373549858
# 4                    38        11         1373-1374             13170764
# ..                  ...       ...               ...                  ...
# 69                   26         3           358-362          20103199339
# 70                  454       NaN              481-  BCI:BCI201700088244
# 71                  NaN        56               NaN                  NaN
# 72                   71         6               NaN                  NaN
# 73                   23         2               NaN                  NaN
#
#                                        DOI     Ref Covidence #  \
# 0                                      NaN  4980.0        #677
# 1                                      NaN  4978.0        #681
# 2                                      NaN  4963.0        #702
# 3                                      NaN  4948.0        #737
# 4                                      NaN  4504.0        #820
# ..                                     ...     ...         ...
# 69                                     NaN     NaN       #3296
# 70                                     NaN     NaN       #3298
# 71                                     NaN     NaN       #3465
# 72  https://dx.doi.org/10.1055/a-1467-5956     NaN       #3621
# 73       10.2174/1389201022666210311140922     NaN       #3724
#
#                      Study                                              Notes  \
# 0             Vorobev 1962  Gillian Clayton (2021-01-18 21:11:12)(Screen):...
# 1          VonDerWeid 2015  Felicity Mehendale (2020-11-10 08:50:45)(Scree...
# 2   Velazquez-Ramirez 2015  Gillian Clayton (2020-12-09 03:42:45)(Screen):...
# 3         vanderVyver 2014  Gillian Clayton (2021-01-18 21:12:28)(Screen):...
# 4          Pappalardo 1982  Gillian Clayton (2021-01-18 21:09:58)(Screen):...
# ..                     ...                                                ...
# 69                Zhu 2010  Kate Homyer (2022-09-30 22:14:27)(Select): Not...
# 70              Zytur 2016  Kate Homyer (2022-10-03 23:16:29)(Select): can...
# 71               Hara 2020  Kate Homyer (2022-12-05 22:48:23)(Select): no ...
# 72            Mueller 2021  Kate Homyer (2022-12-06 01:29:45)(Select): Not...
# 73             Sharma 2022  Kate Homyer (2022-12-02 01:00:56)(Select): no ...
#
#    Tags            decision
# 0   NaN       Decision.EXCL
# 1   NaN       Decision.EXCL
# 2   NaN       Decision.EXCL
# 3   NaN       Decision.EXCL
# 4   NaN       Decision.EXCL
# ..  ...                 ...
# 69  NaN  Decision.FT_INCOMP
# 70  NaN  Decision.FT_INCOMP
# 71  NaN  Decision.FT_INCOMP
# 72  NaN  Decision.FT_INCOMP
# 73  NaN  Decision.FT_INCOMP
#
# [74 rows x 19 columns]

# %%
# No abstract
len_before = len(full_df)
full_df = full_df[~full_df.Abstract.isnull()]
print(f'{len_before - len(full_df)} rows removed due to no abstract')
# Out:
# 126 rows removed due to no abstract

# %%
# Remove papers which seem to have been excluded purely due to lack of full text rather
# than based on the content of the title/abstract.
# Most papers marked as missing full text are FT_INCOMP - these are OK to keep.
to_remove = [443, 460, 2035, 2107, 2590, 2596, 2597, 2598, 2600, 2601, 2606]
len_before = len(full_df)
full_df = full_df.drop(to_remove)
print(f'{len_before - len(full_df)} rows removed - exclusion due to missing full text')
# Out:
# 11 rows removed - exclusion due to missing full text

# %%
# Remove papers removed due to non-English text (also some FT_INCOMPL where the abstract
# was English and approved but full text not English -- these we leave)
to_remove = [439, 664, 2185]
len_before = len(full_df)
full_df = full_df.drop(to_remove)
print(f'{len_before - len(full_df)} rows removed - exclusion due to full text not English')
# Out:
# 3 rows removed - exclusion due to full text not English

# %%
full_df[full_df.Notes.apply(is_important_note)]
# Out:
#       index                                              Title  \
# 72       72  Effectiveness of individual or combined saniti...
# 187     187  Two-year follow-up study of the effect of acid...
# 615     615  Mechanisms of ultraviolet disinfection and chl...
# 1201   1201  The dimensional stability of dental impression...
# 2515    101  Light up ClO(-) in live cells using an aza-cou...
# ...     ...                                                ...
# 3635   1027  Comparison of disinfectants for drinking water...
# 3650   1042  Electrolyzed Water Generated On-Site as a Prom...
# 3663   1055  A comparative experiment on the three kinds of...
# 3701   1093  A Concept for the Reduction of Mucosal SARS-Co...
# 3722   1114  Evaluation of Decontamination Efficacy of Elec...
#
#                                                 Authors  \
# 72           Yuk, H. G.; Bartz, J. A.; Schneider, K. R.
# 187   Tanaka, H.; Honma, S.; Nishi, M.; Igarashi, T....
# 615   Xu, L. M.; Zhang, C. M.; Xu, P. C.; Wang, X. C...
# 1201    Martin, N.; Martin, M. V.; Jedynakiewicz, N. M.
# 2515       Fan, J.; Mu, H.; Zhu, H.; Wang, J.; Peng, X.
# ...                                                 ...
# 3635  Choi, Y.; Byun, S. H.; Jang, H. J.; Kim, S. E....
# 3650                    Farah, R. I.; Al-Haj Ali, S. N.
# 3663  Hara, Norika; Fujita, Shoichi; Satake, Yuko; N...
# 3701             Mueller, C. A.; Winter, M.; Renner, B.
# 3722  Sharma, A. K.; Shukla, S. K.; Kalonia, A.; Sha...
#
#                                                Abstract  Published Year  \
# 72    Unwaxed, green tomatoes ('Florida 47' cultivar...          2005.0
# 187   Acid fog is a complex mixture of atomospheric ...          1996.0
# 615   Traditional culture methods may underestimate ...          2018.0
# 1201  OBJECTIVES: This investigation examined the ef...          2007.0
# 2515  Hypochlorous acid (HClO)/hypochlorite (ClO(-))...          2015.0
# ...                                                 ...             ...
# 3635  The feasibility of on-site generated chlorine ...          2022.0
# 3650  Electrolyzed water is a safe, broad-spectrum b...          2021.0
# 3663  Xanthomonas citri pv. citri and X. citri pv. a...          2020.0
# 3701  During the next few months or years, vaccinati...          2021.0
# 3722  Background: Sulfur Mustard is a strong vesican...          2022.0
#
#       Published Month                                            Journal  \
# 72                NaN                            Journal of Food Science
# 187               NaN                                       Intern. Med.
# 615               NaN                                   J. Environ. Sci.
# 1201              NaN  Dental materials : official publication of the...
# 2515              NaN                                        The Analyst
# ...               ...                                                ...
# 3635              NaN                 Environmental Engineering Research
# 3650              NaN                         Frontiers in Public Health
# 3663              NaN  Research Bulletin of the Plant Protection Serv...
# 3701              NaN                                      Drug Research
# 3722              NaN               Current Pharmaceutical Biotechnology
#
#      Volume Issue      Pages     Accession Number  \
# 72       70     9  M409-M414          20063008118
# 187      35     2    100-104  WOS:A1996UA20200005
# 615      65   NaN    356-366  WOS:000427600600035
# 1201     23     6    760-768             47231825
# 2515    140    13  4594-4598            608359278
# ...     ...   ...        ...                  ...
# 3635     27     1        NaN                  NaN
# 3650      9   NaN        NaN                  NaN
# 3663    NaN    56        NaN                  NaN
# 3701     71     6        NaN                  NaN
# 3722     23     2        NaN                  NaN
#
#                                                     DOI      Ref Covidence #  \
# 72    http://dx.doi.org/10.1111/j.1365-2621.2005.tb0...  10236.0        #117
# 187                     10.2169/internalmedicine.35.100   8339.0        #293
# 615                           10.1016/j.jes.2017.07.006   8529.0        #969
# 1201     http://dx.doi.org/10.1016/j.dental.2007.01.004   4323.0       #1873
# 2515               http://dx.doi.org/10.1039/c5an00777a   3753.0       #2508
# ...                                                 ...      ...         ...
# 3635                               10.4491/eer.2020.543      NaN       #3381
# 3650       https://dx.doi.org/10.3389/fpubh.2021.629142      NaN       #3434
# 3663                                                NaN      NaN       #3465
# 3701             https://dx.doi.org/10.1055/a-1467-5956      NaN       #3621
# 3722                  10.2174/1389201022666210311140922      NaN       #3724
#
#              Study                                              Notes Tags  \
# 72        Yuk 2005  Felicity Mehendale (2020-11-10 06:49:20)(Scree...  NaN
# 187    Tanaka 1996  Gillian Clayton (2021-01-08 03:13:55)(Screen):...  NaN
# 615        Xu 2018  Felicity Mehendale (2020-11-29 08:18:28)(Scree...  NaN
# 1201   Martin 2007  Kayla Ostrishko (2020-11-14 11:54:19)(Screen):...  NaN
# 2515      Fan 2015  Kate Homyer (2022-05-25 23:26:27)(Screen): Sou...  NaN
# ...            ...                                                ...  ...
# 3635     Choi 2022  Gillian Clayton (2022-09-29 23:14:08)(Screen):...  NaN
# 3650    Farah 2021  Gillian Clayton (2022-09-29 23:48:18)(Screen):...  NaN
# 3663     Hara 2020  Kate Homyer (2022-12-05 22:48:23)(Select): no ...  NaN
# 3701  Mueller 2021  Kate Homyer (2022-12-06 01:29:45)(Select): Not...  NaN
# 3722   Sharma 2022  Kate Homyer (2022-12-02 01:00:56)(Select): no ...  NaN
#
#                 decision  orig_index
# 72         Decision.EXCL          72
# 187        Decision.EXCL         187
# 615        Decision.EXCL         615
# 1201       Decision.EXCL        1201
# 2515      Decision.CONFL         101
# ...                  ...         ...
# 3635  Decision.FT_INCOMP        1027
# 3650  Decision.FT_INCOMP        1042
# 3663  Decision.FT_INCOMP        1055
# 3701  Decision.FT_INCOMP        1093
# 3722  Decision.FT_INCOMP        1114
#
# [62 rows x 19 columns]

# %%
# label as positive everything where at least one reviewer thought it should
# get beyond abstract screening
full_df['label'] = full_df.decision.apply(lambda v: 1 if v.value > 0 else 0)
# Out:
#       index                                              Title  \
# 0         0  Simultaneous removal of tetracycline and disin...
# 1         1  A practical method for the calculation of liqu...
# 2         2  Toward better microbial safety of wheat sprout...
# 3         3  Functional collaboration of biofilm-cathode el...
# 4         4  Continuous synthesis of graphene sheets by spr...
# ...     ...                                                ...
# 3842     91  In Vitro Antibacterial Activity of Hydrogen Pe...
# 3843     92  Inactivation of bacteria causing soft rot dise...
# 3844     93  Application of Neutral Electrolyzed Water on p...
# 3845     94  Electrochemically activated solution as bladde...
# 3846     95  Kinetics of Bacterial Inactivation by Peroxyni...
#
#                                                 Authors  \
# 0     Zuo, S.; Zhang, Y.; Ren, G.; Pan, Y.; Zhang, Q...
# 1                            Zuend, A.; Seinfeld, J. H.
# 2                              Zudyte, B.; Luksiene, Z.
# 3                                     Zou, H.; Wang, Y.
# 4       Zou, B.; Wang, X. X.; Huang, X. X.; Wang, J. N.
# ...                                                 ...
# 3842  Raval, Y. S.; Flurin, L.; Mohamed, A.; Greenwo...
# 3843  Song, Hyeyeon; Lee, Jae Yung; Lee, Hae-Won; Ha...
# 3844  Torres-Rosales, E.; Rivera-Garcia, A.; Rosario...
# 3845  Weyler, M.; Jaekel, A.; Kirschner-Hermanns, R....
# 3846  Yokoyama, T.; Miyazaki, S.; Akagi, H.; Ikawa, ...
#
#                                                Abstract  Published Year  \
# 0     Pharmaceutical and personal care products as o...          2019.0
# 1     Liquid mixtures containing a variety of organi...          2013.0
# 2     Sprouted seeds are gaining popularity worldwid...          2019.0
# 3     A distinctive process (BCE-MFC) was developed ...          2019.0
# 4     Graphene sheets (GNS) were synthesized continu...          2015.0
# ...                                                 ...             ...
# 3842  Hydrogen peroxide (H2O2) and hypochlorous acid...          2021.0
# 3843  Slightly acidic electrolyzed water (SAEW), an ...          2021.0
# 3844  Physicochemical and microbiological properties...          2020.0
# 3845  AIMS: Driven by increasing awareness of antibi...          2021.0
# 3846  Low-temperature atmospheric-pressure plasma ha...          2021.0
#
#       Published Month                                            Journal  \
# 0                 NaN                     Journal of Hazardous Materials
# 1                 NaN                               Fluid Phase Equilib.
# 2                 NaN                         Photochem. Photobiol. Sci.
# 3                 NaN  Environmental science and pollution research i...
# 4                 NaN                            Chemical Communications
# ...               ...                                                ...
# 3842              NaN              Antimicrobial Agents and Chemotherapy
# 3843              NaN                                       Food Control
# 3844              NaN                                 Scientific Reports
# 3845              NaN                         Neurourology & Urodynamics
# 3846              NaN               Applied & Environmental Microbiology
#
#      Volume Issue        Pages     Accession Number  \
# 0       368   NaN      771-777           2001546732
# 1       337   NaN      201-213  WOS:000315325500027
# 2        18    10    2521-2530  WOS:000489635100014
# 3        26    22  23061-23069            628271164
# 4        51     4      741-744            600732879
# ...     ...   ...          ...                  ...
# 3842     65     5          NaN                  NaN
# 3843    128   NaN          NaN                  NaN
# 3844     10     1          NaN                  NaN
# 3845     40     7          NaN                  NaN
# 3846     87     2          NaN                  NaN
#
#                                                   DOI     Ref Covidence #  \
# 0     http://dx.doi.org/10.1016/j.jhazmat.2019.02.005  5202.0          #1
# 1                         10.1016/j.fluid.2012.09.034  8644.0          #2
# 2                                  10.1039/c9pp00157c  8643.0          #3
# 3        http://dx.doi.org/10.1007/s11356-019-05617-w  5201.0          #4
# 4                http://dx.doi.org/10.1039/c4cc08197h  5200.0          #5
# ...                                               ...     ...         ...
# 3842                             10.1128/aac.01966-20     NaN       #3680
# 3843                   10.1016/j.foodcont.2021.108217     NaN       #3739
# 3844    https://dx.doi.org/10.1038/s41598-020-76931-4     NaN       #3766
# 3845             https://dx.doi.org/10.1002/nau.24745     NaN       #3799
# 3846          https://dx.doi.org/10.1128/AEM.01860-20     NaN       #3830
#
#                     Study                                              Notes  \
# 0                Zuo 2019                                                NaN
# 1              Zuend 2013                                                NaN
# 2             Zudyte 2019                                                NaN
# 3                Zou 2019                                                NaN
# 4                Zou 2015                                                NaN
# ...                   ...                                                ...
# 3842           Raval 2021                                                NaN
# 3843            Song 2021                                                NaN
# 3844  Torres-Rosales 2020                                                NaN
# 3845          Weyler 2021                                                NaN
# 3846        Yokoyama 2021  Kate Homyer (2022-08-23 03:14:15)(Screen): com...
#
#                                          Tags          decision  orig_index  \
# 0                                         NaN     Decision.EXCL           0
# 1                                         NaN     Decision.EXCL           1
# 2                                         NaN     Decision.EXCL           2
# 3                                         NaN     Decision.EXCL           3
# 4                                         NaN     Decision.EXCL           4
# ...                                       ...               ...         ...
# 3842                Setting - Clinical, human  Decision.FT_INCL          91
# 3843                Setting - Food processing  Decision.FT_INCL          92
# 3844                Setting - Food processing  Decision.FT_INCL          93
# 3845                Setting - Clinical, human  Decision.FT_INCL          94
# 3846  Setting - Water/Environmental treatment  Decision.FT_INCL          95
#
#       label
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ...     ...
# 3842      1
# 3843      1
# 3844      1
# 3845      1
# 3846      1
#
# [3707 rows x 20 columns]

# %%
# so we can distinguish this when we get other reviews
full_df['review_id'] = 121733

# %%
len(full_df), full_df.label.sum()
# Out:
# (3707, 1373)

# %%
simplify_columns(full_df).to_csv('review_121733/full.csv')

# %%
# create test/val/train splits
import numpy as np

simple_df = full_df[['Title', 'Abstract', 'label', 'review_id']].rename(columns={
    'Title': 'title',
    'Abstract': 'abstract',
})

rng = np.random.default_rng(24)
shuffled_df = simple_df.sample(frac=1)

splits = (0.10, 0.10, 0.8)
thresholds = [np.ceil(sum(splits[:i+1]) * len(shuffled_df)).astype(int) for i in range(len(splits))]
test_df = shuffled_df[:thresholds[0]]
val_df = shuffled_df[thresholds[0]:thresholds[1]]
train_df = shuffled_df[thresholds[1]:thresholds[2]]

len(test_df), len(val_df), len(train_df)
# Out:
# (371, 371, 2965)

# %% [markdown]
# ### Review 258698
#
# In this review all excluded papers have a reason for exclusion in the 'Notes' section. However, it seems to be something that's been selected out of a narrow range of generic options and not always accurate, e.g. #412 in excluded says 'wrong type of evidence' but also has a manual note saying it's abstract only and the same research as #411, which is included
#
# Only small number of rows that say excluded due to no full paper and the like; have excluded by adding a preproc_tag column with value 'remove'.
#
# There's only about 200 papers in this set - feels too small to do train/dev/test splits.

# %%
import pandas as pd

# %%
included = pd.read_csv('review_258698/review_258698_included_csv_20240427023944.csv')
excluded = pd.read_csv('review_258698/review_258698_excluded_csv_20240427023950.csv')

included['label'] = 1
excluded['label'] = 0

full_df = pd.concat([excluded, included])
full_df['orig_index'] = full_df.index
full_df = full_df.reset_index()
full_df = full_df[full_df.preproc_tag != 'remove']

full_df = full_df[~full_df.Abstract.isnull()]
full_df
# Out:
#      index                                              Title  \
# 0        0  Rapid Ethical Assessment on Informed Consent C...
# 1        1  Management of type 1 diabetes in low- and midd...
# 2        2  Pregnant women's experiences with an integrate...
# 3        3  Establishment of COVID-19 testing laboratory i...
# 4        4  Malaria diagnosis and treatment behaviors amon...
# ..     ...                                                ...
# 217    120  Caregiver experience and perceived acceptabili...
# 218    121  Integrated point-of-care testing (POCT) for HI...
# 219    122  Decentralization of health care to HIV-AIDS fo...
# 220    123  Dengue rapid diagnostic tests: Health professi...
# 221    124  A qualitative study of health professionals' u...
#
#                                                Authors  \
# 0    Abay, Serebe; Addissie, Adamu; Davey, Gail; Fa...
# 1    Abdraimova, Aida; Besancon, Stephane; Portocar...
# 2    Abejirinde, I. O. O.; Douwes, R.; Bardaji, A.;...
# 3    Abera, Adugna; Belay, Habtamu; Zewude, Aboma; ...
# 4    Aborigo, R. A.; Atuguba, F.; Chatio, S.; Adoct...
# ..                                                 ...
# 217  Yee, WinLei; Than, KyuKyu; Mohamed, Y.; Htay, ...
# 218  Young, N.; Achieng, F.; Desai, M.; Phillips-Ho...
# 219               Zambenedetti, G.; da Silva, R. A. N.
# 220      Zongo, S.; Carabali, M.; Munoz, M.; Ridde, V.
# 221     Zongo, Sylvie; Farquet, Valerie; Ridde, Valery
#
#                                               Abstract  Published Year  \
# 0    BACKGROUND: Informed consent is a key componen...            2016
# 1    AIMS: To describe and compare the health syste...            2022
# 2    Background: Quality antenatal care (ANC) is re...            2018
# 3    The Coronavirus pandemic is recording unpreced...            2020
# 4    Globally, malaria control programmes are threa...            2011
# ..                                                 ...             ...
# 217  Background: The majority of HIV infection amon...            2020
# 218  Background: HIV, syphilis, malaria and anaemia...            2019
# 219  In this article,we seek to identify and discus...            2016
# 220  Objectives: Dengue fever remains unrecognized ...            2018
# 221  BACKGROUND: Since 2012, rapid diagnostic tests...            2016
#
#     Published Month                                            Journal Volume  \
# 0               NaN                                           PLoS ONE   11.0
# 1               NaN  Diabetic medicine : a journal of the British D...   39.0
# 2               NaN                       BMC Pregnancy and Childbirth   18.0
# 3               NaN                               Global Health Action   13.0
# 4               NaN  American Journal of Tropical Medicine and Hygiene   85.0
# ..              ...                                                ...    ...
# 217             NaN                                           PLoS ONE     15
# 218             NaN                       BMC Health Services Research     19
# 219             NaN                                             Physis     26
# 220             NaN                                 SAGE Open Medicine      6
# 221             NaN                                    Malaria Journal     15
#
#           Issue  Pages  Accession Number  \
# 0             6    NaN               NaN
# 1             8    NaN               NaN
# 2           209    NaN               NaN
# 3             1    NaN               NaN
# 4    6 SUPPL. 1    NaN               NaN
# ..          ...    ...               ...
# 217          10    NaN               NaN
# 218          74    NaN               NaN
# 219           3    NaN               NaN
# 220         NaN    NaN               NaN
# 221         NaN    NaN               NaN
#
#                                                  DOI  Ref Covidence #  \
# 0    https://dx.doi.org/10.1371/journal.pone.0157056  NaN         #43
# 1               https://dx.doi.org/10.1111/dme.14891  NaN         #64
# 2        http://dx.doi.org/10.1186/s12884-018-1853-7  NaN         #71
# 3                      10.1080/16549716.2020.1841963  NaN         #73
# 4                                                NaN  NaN         #81
# ..                                               ...  ...         ...
# 217   http://dx.doi.org/10.1371/journal.pone.0241245  NaN       #6809
# 218      http://dx.doi.org/10.1186/s12913-018-3844-9  NaN       #6846
# 219                  10.1590/S0103-73312016000300005  NaN       #6902
# 220      https://dx.doi.org/10.1177/2050312118794589  NaN       #7044
# 221     https://dx.doi.org/10.1186/s12936-016-1241-6  NaN       #7045
#
#                  Study                                       Notes  \
# 0            Abay 2016       Exclusion reason: Wrong test format;
# 1      Abdraimova 2022      Exclusion reason: Wrong study design;
# 2      Abejirinde 2018      Exclusion reason: Wrong study design;
# 3           Abera 2020           Exclusion reason: Wrong setting;
# 4         Aborigo 2011  Exclusion reason: Wrong type of evidence;
# ..                 ...                                         ...
# 217           Yee 2020                                         NaN
# 218         Young 2019                                         NaN
# 219  Zambenedetti 2016                                         NaN
# 220         Zongo 2018                                         NaN
# 221         Zongo 2016                                         NaN
#
#                                                   Tags preproc_tag  label  \
# 0    Interesting-Non-empirical (review article, com...         NaN      0
# 1                                                  NaN         NaN      0
# 2                                                  NaN         NaN      0
# 3                                                  NaN         NaN      0
# 4                                                  NaN         NaN      0
# ..                                                 ...         ...    ...
# 217                                                NaN         NaN      1
# 218                                                NaN         NaN      1
# 219                                                NaN         NaN      1
# 220                                                NaN         NaN      1
# 221                                                NaN         NaN      1
#
#      orig_index
# 0             0
# 1             1
# 2             2
# 3             3
# 4             4
# ..          ...
# 217         120
# 218         121
# 219         122
# 220         123
# 221         124
#
# [210 rows x 20 columns]

# %%
full_df.Notes.unique()
# Out:
# array(['Exclusion reason: Wrong test format; ',
#        'Exclusion reason: Wrong study design; ',
#        'Exclusion reason: Wrong setting; ',
#        'Exclusion reason: Wrong type of evidence; ',
#        'Exclusion reason: Wrong phenomena of interest; ',
#        'Exclusion reason: Wrong perspective; ',
#        'Exclusion reason: Wrong environment; ',
#        'Exclusion reason: Wrong type of evidence; Janet Perkins (2022-10-28 17:54:14)(Select): Conference proceedings; ',
#        'Exclusion reason: Wrong environment; Jasmin Rostron (2022-10-28 21:24:00)(Select): interesting; ',
#        nan], dtype=object)

# %%
title_counts = full_df.groupby('Title').count()
dup_titles = title_counts[title_counts.Authors > 1]
dup_titles
# Out:
# Empty DataFrame
# Columns: [index, Authors, Abstract, Published Year, Published Month, Journal, Volume, Issue, Pages, Accession Number, DOI, Ref, Covidence #, Study, Notes, Tags, preproc_tag, label, orig_index]
# Index: []

# %%
full_df['review_id'] = 258698

# create test/val/train splits
import numpy as np

simple_df = full_df[['Title', 'Abstract', 'label', 'review_id']].rename(columns={
    'Title': 'title',
    'Abstract': 'abstract',
})

rng = np.random.default_rng(24)
shuffled_df = simple_df.sample(frac=1)

splits = (0.10, 0.10, 0.8)
thresholds = [np.ceil(sum(splits[:i+1]) * len(shuffled_df)).astype(int) for i in range(len(splits))]
test_df = shuffled_df[:thresholds[0]]
val_df = shuffled_df[thresholds[0]:thresholds[1]]
train_df = shuffled_df[thresholds[1]:thresholds[2]]

len(test_df), len(val_df), len(train_df)
# Out:
# (21, 21, 168)

# %%
simple_df.to_csv('review_258698/full.csv')

# %%
eval = pd.read_csv('review_334317/zero-shot-eval.csv', index_col=0)
full = pd.read_csv('review_334317/full.csv', index_col=0)
free_idxs = set(full.index) - set(eval.index)
egs_df = full.loc[list(free_idxs)]
pos = egs_df[egs_df.label == 1].sample(5)
neg = egs_df[egs_df.label == 0].sample(5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 5
#       3 free_idxs = set(full.index) - set(eval.index)
#       4 egs_df = full.loc[list(free_idxs)]
# ----> 5 pos = egs_df[egs_df.label == 1].sample(5)
#       6 neg = egs_df[egs_df.label == 0].sample(5)
#
# File ~/anaconda3/envs/diss/lib/python3.12/site-packages/pandas/core/generic.py:6118, in NDFrame.sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    6115 if weights is not None:
#    6116     weights = sample.preprocess_weights(self, weights, axis)
# -> 6118 sampled_indices = sample.sample(obj_len, size, replace, weights, rs)
#    6119 result = self.take(sampled_indices, axis=axis)
#    6121 if ignore_index:
#
# File ~/anaconda3/envs/diss/lib/python3.12/site-packages/pandas/core/sample.py:152, in sample(obj_len, size, replace, weights, random_state)
#     149     else:
#     150         raise ValueError("Invalid weights: weights sum to zero")
# --> 152 return random_state.choice(obj_len, size=size, replace=replace, p=weights).astype(
#     153     np.intp, copy=False
#     154 )
#
# File numpy/random/mtrand.pyx:945, in numpy.random.mtrand.RandomState.choice()
#
# ValueError: a must be greater than 0 unless no samples are taken

# %% [markdown]
# ### Multi-review datasets

# %%
def make_multi_review_df(reviews, min_pos_sample_size=98, max_pos_sample_size=None, balance=True):
    frames = []
    for path in Path('.').glob('*/full.csv'):        
        df = pd.read_csv(path, index_col=0)
        rev_id = df.iloc[0].review_id
        if not rev_id in reviews:
            continue
        num_pos = df.label.sum()
        if min_pos_sample_size > num_pos:
            raise Exception(f'Not enough positive examples in {path}')
        if max_pos_sample_size and max_pos_sample_size < num_pos:
            sample_num = max_pos_sample_size
        elif balance:
            sample_num = min_pos_sample_size
        else:
            sample_num = num_pos
        df = pd.concat([
            df[df.label == 1].sample(sample_num),
            df[df.label == 0].sample(sample_num),
        ])
        df['df_index'] = df.index
        df = df.sample(frac=1, ignore_index=True)
        frames.append(df)

    if balance:
        dataset = pd.concat(frames).sort_index()
    else:
        dataset = pd.concat(frames).sample(frac=1, ignore_index=True)
    return dataset

# %%
import re
import numpy as np

def make_multi_review_val_df(reviews, review_sample_size=97):
    frames = []
    for val_split_path in Path('.').glob('*/val_split.txt'):
        match = re.search(r'review_(\d{6})', str(val_split_path))
        rev_id = int(match.groups()[0])
        if not rev_id in reviews:
            continue
            
        df_path = val_split_path.parent / 'full.csv'
        df = pd.read_csv(df_path, index_col=0)
        df['df_index'] = df.index
        val_split = np.genfromtxt(val_split_path)
        df = df.loc[val_split].sample(review_sample_size, ignore_index=True)
        frames.append(df)
        
    dataset = pd.concat(frames).sort_index()
    return dataset

# %%
df = make_multi_review_df([117787, 121733, 165805, 258698, 287708, 334317, 378562])
path = f'multi-review-all.csv'
df[['review_id', 'df_index']].to_csv(path, index=False)

# %%
reviews = {117787, 121733, 165805, 258698, 287708, 334317, 378562}
for excl_review in reviews:
    incl_reviews = reviews - {excl_review}
    df = make_multi_review_df(incl_reviews)
    path = f'multi-review-excl-{excl_review}.csv'
    df[['review_id', 'df_index']].to_csv(path, index=False)

# %%
unbal = make_multi_review_df([121733, 165805, 258698, 287708, 334317, 378562], max_pos_sample_size=500, balance=False)
unbal[['review_id', 'df_index']].to_csv('multi-review-unbal-excl-117787.csv', index=False)

# %%
df = pd.read_csv('multi-review-unbal-excl-117787.csv')

# %%
# adhoc set to compare performance on 378562
incl_reviews = [258698, 165805, 287708]
df = make_multi_review_df([258698, 165805, 287708], min_pos_sample_size=196)
set_id = '-'.join([str(rev) for rev in incl_reviews])
path = f'three-review-Z-{set_id}.csv'
df[['review_id', 'df_index']].to_csv(path, index=False)

# %%
reviews = {117787, 121733, 165805, 258698, 287708, 334317, 378562}
top_four = [121733, 165805, 258698, 287708]
letters = 'ABCDEFG'
for i, eval_review in enumerate(reviews):
    incl_reviews = [rev for rev in top_four if rev != eval_review][:3]
    df = make_multi_review_df(incl_reviews, min_pos_sample_size=196)
    set_id = '-'.join([str(rev) for rev in incl_reviews])
    path = f'three-review-{letters[i]}-{set_id}.csv'
    df[['review_id', 'df_index']].to_csv(path, index=False)
    print('Saved', path)

    val_reviews = reviews - set(incl_reviews)
    val_df = make_multi_review_val_df(val_reviews)
    set_id = '-'.join([str(rev) for rev in val_reviews])
    path = f'val-split-{letters[i]}-{set_id}.csv'
    val_df[['review_id', 'df_index']].to_csv(path, index=False)
    print('Saved', path)
# Out:
# Saved three-review-A-121733-165805-258698.csv
# Saved val-split-A-378562-117787-287708-334317.csv
# Saved three-review-B-165805-258698-287708.csv
# Saved val-split-B-334317-378562-117787-121733.csv
# Saved three-review-C-121733-165805-287708.csv
# Saved val-split-C-378562-117787-334317-258698.csv
# Saved three-review-D-121733-165805-258698.csv
# Saved val-split-D-378562-117787-287708-334317.csv
# Saved three-review-E-121733-165805-258698.csv
# Saved val-split-E-378562-117787-287708-334317.csv
# Saved three-review-F-121733-165805-258698.csv
# Saved val-split-F-378562-117787-287708-334317.csv
# Saved three-review-G-121733-258698-287708.csv
# Saved val-split-G-378562-117787-334317-165805.csv

# %%
for i, eval_review in enumerate(reviews):
    incl_reviews = [rev for rev in top_four if rev != eval_review][:3]
    print('Review', eval_review)
    print('Set', letters[i])
    print('-'.join([str(rev) for rev in incl_reviews]))
    print()
    i += 1
# Out:
# Review 378562
# Set A
# 121733-165805-258698
#
# Review 121733
# Set B
# 165805-258698-287708
#
# Review 258698
# Set C
# 121733-165805-287708
#
# Review 117787
# Set D
# 121733-165805-258698
#
# Review 287708
# Set E
# 121733-165805-258698
#
# Review 334317
# Set F
# 121733-165805-258698
#
# Review 165805
# Set G
# 121733-258698-287708

# %%
from itertools import combinations

reviews = [117787, 121733, 165805, 258698, 287708, 334317, 378562]

for incl_reviews in combinations(reviews, 4):
    set_id = '-'.join([str(rev) for rev in incl_reviews])
    df = make_multi_review_val_df(incl_reviews)
    path = f'val_split-{set_id}.csv'
    df[['review_id', 'df_index']].to_csv(path, index=False)
    print('Saved', path)
# Out:
# Saved val_split-117787-121733-165805-258698.csv
# Saved val_split-117787-121733-165805-287708.csv
# Saved val_split-117787-121733-165805-334317.csv
# Saved val_split-117787-121733-165805-378562.csv
# Saved val_split-117787-121733-258698-287708.csv
# Saved val_split-117787-121733-258698-334317.csv
# Saved val_split-117787-121733-258698-378562.csv
# Saved val_split-117787-121733-287708-334317.csv
# Saved val_split-117787-121733-287708-378562.csv
# Saved val_split-117787-121733-334317-378562.csv
# Saved val_split-117787-165805-258698-287708.csv
# Saved val_split-117787-165805-258698-334317.csv
# Saved val_split-117787-165805-258698-378562.csv
# Saved val_split-117787-165805-287708-334317.csv
# Saved val_split-117787-165805-287708-378562.csv
# Saved val_split-117787-165805-334317-378562.csv
# Saved val_split-117787-258698-287708-334317.csv
# Saved val_split-117787-258698-287708-378562.csv
# Saved val_split-117787-258698-334317-378562.csv
# Saved val_split-117787-287708-334317-378562.csv
# Saved val_split-121733-165805-258698-287708.csv
# Saved val_split-121733-165805-258698-334317.csv
# Saved val_split-121733-165805-258698-378562.csv
# Saved val_split-121733-165805-287708-334317.csv
# Saved val_split-121733-165805-287708-378562.csv
# Saved val_split-121733-165805-334317-378562.csv
# Saved val_split-121733-258698-287708-334317.csv
# Saved val_split-121733-258698-287708-378562.csv
# Saved val_split-121733-258698-334317-378562.csv
# Saved val_split-121733-287708-334317-378562.csv
# Saved val_split-165805-258698-287708-334317.csv
# Saved val_split-165805-258698-287708-378562.csv
# Saved val_split-165805-258698-334317-378562.csv
# Saved val_split-165805-287708-334317-378562.csv
# Saved val_split-258698-287708-334317-378562.csv

# %%
full_df = pd.concat([
    pd.read_csv(path, index_col=0)
    for path in Path('.').glob('*/full.csv')
])

# %%
full_df = full_df.set_index([full_df.index, full_df.review_id])

# %%
split_df = pd.read_csv('val-split-A-378562-117787-287708-334317.csv')
indexer = [(row.df_index, row.review_id) for _, row in split_df.iterrows()]
full_df.loc[indexer]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 3
#       1 split_df = pd.read_csv('val-split-A-378562-117787-287708-334317.csv')
#       2 indexer = [(row.df_index, row.review_id) for _, row in split_df.iterrows()]
# ----> 3 full_df.loc[indexer]
#
# File ~/anaconda3/envs/diss/lib/python3.12/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/anaconda3/envs/diss/lib/python3.12/site-packages/pandas/core/indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#    1417     if hasattr(key, "ndim") and key.ndim > 1:
#    1418         raise ValueError("Cannot index with multidimensional key")
# -> 1420     return self._getitem_iterable(key, axis=axis)
#    1422 # nested tuple slicing
#    1423 if is_nested_tuple(key, labels):
#
# File ~/anaconda3/envs/diss/lib/python3.12/site-packages/pandas/core/indexing.py:1360, in _LocIndexer._getitem_iterable(self, key, axis)
#    1357 self._validate_key(key, axis)
#    1359 # A collection of keys
# -> 1360 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1361 return self.obj._reindex_with_indexers(
#    1362     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1363 )
#
# File ~/anaconda3/envs/diss/lib/python3.12/site-packages/pandas/core/indexing.py:1558, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1555 ax = self.obj._get_axis(axis)
#    1556 axis_name = self.obj._get_axis_name(axis)
# -> 1558 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1560 return keyarr, indexer
#
# File ~/anaconda3/envs/diss/lib/python3.12/site-packages/pandas/core/indexes/multi.py:2766, in MultiIndex._get_indexer_strict(self, key, axis_name)
#    2763     self._raise_if_missing(key, indexer, axis_name)
#    2764     return self[indexer], indexer
# -> 2766 return super()._get_indexer_strict(key, axis_name)
#
# File ~/anaconda3/envs/diss/lib/python3.12/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~/anaconda3/envs/diss/lib/python3.12/site-packages/pandas/core/indexes/multi.py:2786, in MultiIndex._raise_if_missing(self, key, indexer, axis_name)
#    2784         raise KeyError(f"{keyarr} not in index")
#    2785 else:
# -> 2786     return super()._raise_if_missing(key, indexer, axis_name)
#
# File ~/anaconda3/envs/diss/lib/python3.12/site-packages/pandas/core/indexes/base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: '[(0, 334317), (8, 334317), (10, 117787), (16, 117787), (17, 117787), (25, 287708), (26, 287708), (26, 334317), (30, 334317), (35, 334317), (39, 117787), (39, 287708), (43, 334317), (44, 378562), (45, 378562), (46, 378562), (47, 378562), (48, 378562), (49, 378562), (57, 117787), (66, 378562), (67, 378562), (73, 378562), (77, 117787), (78, 378562), (81, 378562), (82, 334317), (88, 378562), (92, 117787), (93, 378562), (95, 378562), (96, 378562)] not in index'

# %%
split_df = pd.read_csv('multi-review-excl-117787.csv')
indexer = [(row.df_index, row.review_id) for _, row in split_df.iterrows()]
full_df.loc[indexer]
# Out:
#                 orig_index                                              title  \
#      review_id
# 371  378562            256  Hidden in Plain Sight: “Neutral” Enclosures fo...
# 3165 258698           2943  The successful containment of COVID-19 outbrea...
# 1110 334317            964  How Can I Feel Safe at Home? Adolescents' Expe...
# 286  165805            274  Relationship Between Bronchial Asthma and COVI...
# 330  121733            330  Amide Link Scission in the Polyamide Active La...
# ...                    ...                                                ...
# 1556 121733           1556  Electrical methods of controlling bacterial ad...
# 3629 334317           3483  Characteristics of intentional acute drug into...
# 57   378562             24  Evidence review for multicomponent interventio...
# 166  165805            154  Underlying Medical Conditions Associated With ...
# 69   258698             69  Feasibility and acceptability of implementing ...
#
#                                                          abstract  label  \
#      review_id
# 371  378562     Politicians and mainstream media in the EU, UK...      0
# 3165 258698     Objectives: A three-member central Rapid Respo...      0
# 1110 334317     Despite the implementation of various national...      0
# 286  165805     <h2>Condition:</h2>Asthma;COVID-19<br><br><h2>...      1
# 330  121733     The volume-averaged amide link scission in the...      0
# ...                                                           ...    ...
# 1556 121733     This review will summarize the significant bod...      0
# 3629 334317     Background/Objectives: The purpose of this stu...      0
# 57   378562     The UK has a routine vaccination schedule cove...      1
# 166  165805     Importance: Information on underlying conditio...      1
# 69   258698     Introduction Early infant diagnosis (EID) of H...      1
#
#                 review_id
#      review_id
# 371  378562        378562
# 3165 258698        258698
# 1110 334317        334317
# 286  165805        165805
# 330  121733        121733
# ...                   ...
# 1556 121733        121733
# 3629 334317        334317
# 57   378562        378562
# 166  165805        165805
# 69   258698        258698
#
# [1176 rows x 5 columns]

# %% [markdown]
# ### Augmented datasets

# %%
full_df = pd.read_csv('review_378562/full.csv', index_col=0)
train_split = np.genfromtxt('review_378562/natural_train_split.txt')
df = full_df.loc[train_split]
reviews = pd.read_csv('reviews.csv', index_col='index')
reviews

# targeting 378562 as train and 334317 as eval
contrast_reviews = [121733, 117787, 165805, 258698, 287708] 
df_jumbled = df[df.label == 1].copy()
df_jumbled['review_id'] = np.random.choice(contrast_reviews, size=len(df_jumbled))
df_jumbled['label'] = 0

total_df = pd.concat([df, df_jumbled], ignore_index=True)
total_df = total_df.sample(frac=1)

total_df.to_csv('aug_cc_nat_378562.csv')

# %%
pd.read_csv('aug_cc_nat_378562.csv', index_col=0)
# Out:
#      orig_index                                              title  \
# 244         517  Spectrality and Thanatic Ethics of Care in Atl...
# 394         199  EVERYBODY HATES A TOURIST: WORLD-TRAVELING, EP...
# 456         174  The effect of mitigation strategies on univers...
# 113         490  Rewriting the Transnational Dimension of Itali...
# 500         109  Counter-urbanisation in pre-pandemic times: di...
# ..          ...                                                ...
# 285         278  IBIA 2021: A Global Conference and Meeting of ...
# 541         457  Public health community engagement with Asian ...
# 277         566  Unloved but Indispensable Logistics: How to Im...
# 419         314               Inspecting Prisons during a pandemic
# 370         581  The Vulnerability Project: Migrant Workers in ...
#
#                                               abstract  label  review_id
# 244  Although the gendered response to moral proble...      0     378562
# 394  Prior to the pandemic of 2020, global tourism ...      0     378562
# 456  Rising levels of anxiety, stress and depressio...      0     378562
# 113  This article investigates how COVID-19 has rew...      0     378562
# 500  The COVID-19 pandemic has stimulated a resurge...      0     378562
# ..                                                 ...    ...        ...
# 285  The proceedings contain 258 papers. The topics...      0     378562
# 541  OBJECTIVES: COVID-19 has posed significant cha...      0     378562
# 277  [...]people should appreciate the role and the...      0     378562
# 419  An interview with Peter Clarke, HM Chief Inspe...      0     378562
# 370  Governments in Singapore, India, and UK have a...      0     378562
#
# [635 rows x 5 columns]

# %%
full_df = pd.read_csv('review_287708/full.csv', index_col=0)
train_split = np.genfromtxt('review_287708/balanced_train_split.txt')
df = full_df.loc[train_split]
reviews = pd.read_csv('reviews.csv', index_col='index')
reviews

# targeting 287708 as train and 288055 as eval
contrast_reviews = [121733, 117787, 165805, 258698, 334317] 
df_jumbled = df[df.label == 1].copy()
df_jumbled['review_id'] = np.random.choice(contrast_reviews, size=len(df_jumbled))
df_jumbled['label'] = 0

total_df = pd.concat([df, df_jumbled])
#total_df = total_df.sample(frac=1)

#total_df.to_csv('aug_cc_287708.csv')

# %%
all_reviews = {378562, 334317, 117787, 258698, 165805, 287708, 121733}

for review in all_reviews:
    rng = np.random.default_rng()
    train_split = np.genfromtxt(f'review_{review}/balanced_train_split.txt')
    rng.shuffle(train_split)
    df = pd.read_csv(f'review_{review}/full.csv', index_col=0).loc[train_split]
    new_rows = []
    for _, row in df.iterrows():
        new_rows.append(row)
        if row.label == 0:
            continue
        aug_row = row.copy()
        aug_row.review_id = rng.choice(contrast_reviews)
        aug_row.label = 0
        new_rows.append(aug_row)

    df = pd.DataFrame(new_rows)
    df = df.reset_index()
    df.rename(columns={'index': 'split_index'}, inplace=True)
    df = df.sample(frac=1)
    if len(df) > 1500:
        df = df[:1500]
    df.to_csv(f'review_{review}/aug_cc.csv')
